# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm 
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
from sklearn.metrics import confusion_matrix

go_track_data = pd.read_csv('data/go_track_tracks.csv')
print(go_track_data)
# Out:
#         id  id_android      speed      time  distance  rating  rating_bus  \
# 0        1           0  19.210586  0.138049     2.652       3           0
# 1        2           0  30.848229  0.171485     5.290       3           0
# 2        3           1  13.560101  0.067699     0.918       3           0
# 3        4           1  19.766679  0.389544     7.700       3           0
# 4        8           0  25.807401  0.154801     3.995       2           0
# ..     ...         ...        ...       ...       ...     ...         ...
# 158  38081          24  30.051732  0.218756     6.574       2           0
# 159  38082          24  30.173788  0.255387     7.706       3           0
# 160  38084          25   1.153772  0.013001     0.015       1           3
# 161  38090          26   0.843223  0.007116     0.006       3           1
# 162  38092          27   1.372998  0.016752     0.023       3           1
#
#      rating_weather  car_or_bus                        linha
# ...

# %%
print(go_track_data.describe())
# Out:
#                  id  id_android       speed        time    distance  \
# count    163.000000  163.000000  163.000000  163.000000  163.000000
# mean   15607.650307    7.386503   16.704738    0.264272    5.302411
# std    18644.257138    7.348742   16.016168    0.292731    7.639011
# min        1.000000    0.000000    0.009779    0.002175    0.001000
# 25%       48.500000    1.000000    1.591016    0.035978    0.034500
# 50%      158.000000    4.000000   16.685368    0.214466    3.995000
# 75%    37991.000000   10.000000   23.915760    0.390572    7.333000
# max    38092.000000   27.000000   96.206029    1.942948   55.770000
#
#            rating  rating_bus  rating_weather  car_or_bus
# count  163.000000  163.000000      163.000000  163.000000
# mean     2.515337    0.386503        0.515337    1.466258
# std      0.679105    0.687859        0.841485    0.500397
# min      1.000000    0.000000        0.000000    1.000000
# 25%      2.000000    0.000000        0.000000    1.000000
# ...

# %%
print(go_track_data.corr())
# Out:
#                       id  id_android     speed      time  distance    rating  \
# id              1.000000    0.610094 -0.098485  0.029410 -0.045866  0.024658
# id_android      0.610094    1.000000  0.072475  0.043123  0.025575  0.110744
# speed          -0.098485    0.072475  1.000000  0.190531  0.594457  0.175497
# time            0.029410    0.043123  0.190531  1.000000  0.661371 -0.157466
# distance       -0.045866    0.025575  0.594457  0.661371  1.000000  0.067579
# rating          0.024658    0.110744  0.175497 -0.157466  0.067579  1.000000
# rating_bus      0.486490    0.155881 -0.199186 -0.114893 -0.154358 -0.151520
# rating_weather  0.597534    0.244098 -0.224698 -0.114535 -0.165319  0.094103
# car_or_bus      0.240600   -0.077846 -0.257872 -0.084028 -0.167561 -0.202823
#
#                 rating_bus  rating_weather  car_or_bus
# id                0.486490        0.597534    0.240600
# id_android        0.155881        0.244098   -0.077846
# ...

# %%
scatter_matrix(go_track_data)
plt.show()

# %%
X = go_track_data[['rating_weather','rating','distance','time','speed','car_or_bus']]
y = go_track_data['rating_bus']
model = LinearRegression()
model.fit(X, y)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# intercept: 3.153895182898938
# slope: [ 0.76651871 -0.70367766  0.01880751 -0.73747293  0.00370453 -0.49671669]

# %%
y_predicted = model.predict(X)
print(y_predicted)
# Out:
# [2.6764148  2.74448295 2.17803495 2.09122734 2.71375746 2.65740968
#  2.78356966 2.2090342  1.98150881 2.19171341 2.61386141 2.58574727
#  2.18794382 2.08938569 2.53728142 2.53728142 2.52279917 2.6377851
#  2.14437583 2.09019156 1.07871623 1.07871623 2.40091893 3.16195473
#  3.16195473 1.91746371 2.67433045 2.52207714 2.67364476 2.65198587
#  2.66510535 2.75201672 2.61170446 2.51810923 2.69488853 2.70351684
#  2.71366144 2.71366144 2.75575873 2.63016333 2.67820379 2.27854567
#  2.27854567 2.43636822 2.64633255 3.03533172 3.03533172 2.8927779
#  2.16555981 2.16012199 2.16252163 2.13677983 2.13764502 2.16811042
#  2.15982025 2.14032372 2.07012061 2.54503879 2.48314328 2.56063499
#  2.32276117 2.32276117 2.65534081 2.65534081 2.76834845 2.76834845
#  2.70342603 2.70342603 2.7355929  2.7355929  2.57527175 2.64610507
#  2.40843542 2.65935132 2.64580516 2.57526359 2.5868011  2.63185603
#  2.15940671 2.71508531 2.09758351 2.11947772 2.16220897 0.84695757
# ...

# %%
rmse = mean_squared_error(y, y_predicted)
r2 = r2_score(y, y_predicted)

print('Root mean squared error: ', rmse)
print('R2 score: ', r2)
# Out:
# Root mean squared error:  0.29733589921948006
# R2 score:  0.35129598403987805

# %%
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 rating   R-squared:                       0.351
# Model:                            OLS   Adj. R-squared:                  0.326
# Method:                 Least Squares   F-statistic:                     14.08
# Date:                Tue, 26 Oct 2021   Prob (F-statistic):           8.93e-13
# Time:                        12:08:33   Log-Likelihood:                -132.44
# No. Observations:                 163   AIC:                             278.9
# Df Residuals:                     156   BIC:                             300.5
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              3.1539      0.178     17.679      0.000       2.802       3.506
# ...

# %%
plt.plot(X, y_predicted, color='b')
# plt.plot(x, y, color='b')
plt.show()
