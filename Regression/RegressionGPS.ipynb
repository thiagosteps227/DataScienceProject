# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import pandas as pd

go_track_data = pd.read_csv('data/go_track_tracks.csv')
print(go_track_data.describe())
print(go_track_data.corr())

scatter_matrix(df)
plt.show()
# Out:
#                  id  id_android       speed        time    distance  \
# count    163.000000  163.000000  163.000000  163.000000  163.000000
# mean   15607.650307    7.386503   16.704738    0.264272    5.302411
# std    18644.257138    7.348742   16.016168    0.292731    7.639011
# min        1.000000    0.000000    0.009779    0.002175    0.001000
# 25%       48.500000    1.000000    1.591016    0.035978    0.034500
# 50%      158.000000    4.000000   16.685368    0.214466    3.995000
# 75%    37991.000000   10.000000   23.915760    0.390572    7.333000
# max    38092.000000   27.000000   96.206029    1.942948   55.770000
#
#            rating  rating_bus  rating_weather  car_or_bus
# count  163.000000  163.000000      163.000000  163.000000
# mean     2.515337    0.386503        0.515337    1.466258
# std      0.679105    0.687859        0.841485    0.500397
# min      1.000000    0.000000        0.000000    1.000000
# 25%      2.000000    0.000000        0.000000    1.000000
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

go_track_data = pd.read_csv('data/go_track_tracks.csv')

X = go_track_data[['rating_bus', 'car_or_bus']]
y = go_track_data['rating_weather']

model = LinearRegression()
model.fit(X,y)

print('intercept', model.intercept_)
print('slope', model.coef_)
# Out:
# intercept -0.40221203129215033
# slope [0.84812517 0.40221203]

# %%
model = LinearRegression()
model.fit(X,y)
print(model.coef_)
print(model.intercept_)
rSquared = model.score(X,y)
print('r squared', rSquared)
# Out:
# [0.84812517 0.40221203]
# -0.40221203129215033
# r squared 0.7378444650727856

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_33972/296428.py in <module>
# ----> 1 plt.scatter(X, y, color='black')
#       2 plt.ylabel("rating_weather")
#       3 plt.Xlabel("rating_bus & car_or_bus ")
#       4 plt.show()
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2888         verts=cbook.deprecation._deprecated_parameter,
#    2889         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2890     __ret = gca().scatter(
#    2891         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2892         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...
